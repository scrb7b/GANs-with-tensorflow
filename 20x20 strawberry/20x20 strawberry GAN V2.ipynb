# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, BatchNormalization, Dropout
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, LeakyReLU
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataset = keras.utils.image_dataset_from_directory(
    '1files/straw',
    color_mode='rgb',
    batch_size=100,
    image_size=(20, 20),
    shuffle=True,
)
# Out:
# Found 743 files belonging to 1 classes.

# %%
images_list = []

for images, labels in dataset:
    images_list.append(images)

images = np.concatenate(images_list, axis=0)

# %%
BUFFER_SIZE = images.shape[0]
BATCH_SIZE = 100

# %%
BUFFER_SIZE = BUFFER_SIZE // BATCH_SIZE * BATCH_SIZE
images = images[:BUFFER_SIZE]

# %%
images.shape
# Out:
# (700, 20, 20, 3)

# %%
images = images / 255

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
hidden_dim = 4

# %%
generator = tf.keras.Sequential([
    
    Dense(5 * 5 * 64, activation='relu'), #5х5
    BatchNormalization(),
    LeakyReLU(),
    Dropout(0.3),
    # Dense(5 * 5 * 256, activation='relu'),
    # BatchNormalization(),
    # LeakyReLU(),
    
  Reshape((5, 5, 64)),
    
  Conv2DTranspose(32, (5, 5), strides=(2, 2), padding='same', activation='relu'),
  BatchNormalization(),
  LeakyReLU(),
  Dropout(0.3),

  Conv2DTranspose(3, (5, 5), strides=(2, 2), padding='same', activation='relu'),
])
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
discriminator = tf.keras.Sequential([

Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[20, 20, 3]),
LeakyReLU(),
Dropout(0.3),

Conv2D(32, (5, 5), strides=(2, 2), padding='same'),
LeakyReLU(),
Dropout(0.3),
    
Flatten(),
Dense(1)

])

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(fake_output):
  loss = cross_entropy(tf.ones_like(fake_output), fake_output)
  return loss

# %%
def discriminator_loss(real_output, fake_output):
  real_loss = cross_entropy(tf.ones_like(real_output), real_output)
  fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
  total_loss = real_loss + fake_loss
  return total_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
@tf.function
def train_step(images):
  noise = tf.random.normal([BATCH_SIZE, hidden_dim])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(noise, training=True) # generate img

    real_output = discriminator(images, training=True) # gradient of real in disc
    fake_output = discriminator(generated_images, training=True) # gradient of generated in disc

    gen_loss = generator_loss(fake_output) # loss of generation 
    disc_loss = discriminator_loss(real_output, fake_output) # loss of discriminator

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables) # calculate gradients 
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables) 

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables)) # apply optimizer 
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

  return gen_loss, disc_loss

# %%
import time
def train(dataset, epochs):
  history = []
  MAX_PRINT_LABEL = 10
  th = BUFFER_SIZE / (BATCH_SIZE * MAX_PRINT_LABEL)

  for epoch in range(1, epochs + 1):
    print(f'{epoch}/{EPOCHS}: ', end='')

    start = time.time()
    n = 0

    gen_loss_epoch = 0
    for image_batch in dataset:
      gen_loss, disc_loss = train_step(image_batch)
      gen_loss_epoch += K.mean(gen_loss)
      if (n % th == 0): print('=', end='')
      n += 1

    history += [gen_loss_epoch / n]
    print(': ' + str(history[-1]))
    print('Время эпохи {} составляет {} секунд'.format(epoch, time.time() - start))

  return history

# %%
EPOCHS = 3000
history = train(train_dataset, EPOCHS)
# Out:
# 1/3000: =: tf.Tensor(1.7574712, shape=(), dtype=float32)
# Время эпохи 1 составляет 0.311290979385376 секунд
# 2/3000: =: tf.Tensor(1.655405, shape=(), dtype=float32)
# Время эпохи 2 составляет 0.24978017807006836 секунд
# 3/3000: =: tf.Tensor(1.8272135, shape=(), dtype=float32)
# Время эпохи 3 составляет 0.27466559410095215 секунд
# 4/3000: =: tf.Tensor(1.7080237, shape=(), dtype=float32)
# Время эпохи 4 составляет 0.26282620429992676 секунд
# 5/3000: =: tf.Tensor(1.8071098, shape=(), dtype=float32)
# Время эпохи 5 составляет 0.2836172580718994 секунд
# 6/3000: =: tf.Tensor(1.7867315, shape=(), dtype=float32)
# Время эпохи 6 составляет 0.27899789810180664 секунд
# 7/3000: =: tf.Tensor(1.7201456, shape=(), dtype=float32)
# Время эпохи 7 составляет 0.2539212703704834 секунд
# 8/3000: =: tf.Tensor(1.7220072, shape=(), dtype=float32)
# Время эпохи 8 составляет 0.27961301803588867 секунд
# 9/3000: =: tf.Tensor(1.7279485, shape=(), dtype=float32)
# Время эпохи 9 составляет 0.31681299209594727 секунд
# 10/3000: =: tf.Tensor(1.7313101, shape=(), dtype=float32)
# Время эпохи 10 составляет 0.2998507022857666 секунд
# 11/3000: =: tf.Tensor(1.7901498, shape=(), dtype=float32)
# Время эпохи 11 составляет 0.31623196601867676 секунд
# 12/3000: =: tf.Tensor(1.8138723, shape=(), dtype=float32)
# Время эпохи 12 составляет 0.284348726272583 секунд
# 13/3000: =: tf.Tensor(1.7509301, shape=(), dtype=float32)
# Время эпохи 13 составляет 0.2993292808532715 секунд
# 14/3000: =: tf.Tensor(1.805958, shape=(), dtype=float32)
# Время эпохи 14 составляет 0.26670336723327637 секунд
# 15/3000: =: tf.Tensor(1.7696506, shape=(), dtype=float32)
# Время эпохи 15 составляет 0.2840535640716553 секунд
# 16/3000: =: tf.Tensor(1.8172683, shape=(), dtype=float32)
# Время эпохи 16 составляет 0.24905037879943848 секунд
# 17/3000: =: tf.Tensor(1.8248873, shape=(), dtype=float32)
# Время эпохи 17 составляет 0.25029563903808594 секунд
# 18/3000: =: tf.Tensor(1.7619264, shape=(), dtype=float32)
# Время эпохи 18 составляет 0.26656317710876465 секунд
# 19/3000: =: tf.Tensor(1.6604675, shape=(), dtype=float32)
# Время эпохи 19 составляет 0.25018739700317383 секунд
# 20/3000: =: tf.Tensor(1.6639448, shape=(), dtype=float32)
# Время эпохи 20 составляет 0.2569127082824707 секунд
# 21/3000: =: tf.Tensor(1.7077696, shape=(), dtype=float32)
# Время эпохи 21 составляет 0.2603600025177002 секунд
# 22/3000: =: tf.Tensor(1.7840315, shape=(), dtype=float32)
# Время эпохи 22 составляет 0.26593589782714844 секунд
# 23/3000: =: tf.Tensor(1.7223121, shape=(), dtype=float32)
# Время эпохи 23 составляет 0.4038529396057129 секунд
# 24/3000: =: tf.Tensor(1.7190588, shape=(), dtype=float32)
# Время эпохи 24 составляет 0.37114548683166504 секунд
# 25/3000: =: tf.Tensor(1.7273086, shape=(), dtype=float32)
# Время эпохи 25 составляет 0.3128163814544678 секунд
# 26/3000: =: tf.Tensor(1.6401201, shape=(), dtype=float32)
# Время эпохи 26 составляет 0.28794431686401367 секунд
# 27/3000: =: tf.Tensor(1.6876345, shape=(), dtype=float32)
# Время эпохи 27 составляет 0.2745320796966553 секунд
# 28/3000: =: tf.Tensor(1.7820355, shape=(), dtype=float32)
# Время эпохи 28 составляет 0.24996209144592285 секунд
# 29/3000: =: tf.Tensor(1.7244791, shape=(), dtype=float32)
# Время эпохи 29 составляет 0.2834157943725586 секунд
# 30/3000: =: tf.Tensor(1.71583, shape=(), dtype=float32)
# Время эпохи 30 составляет 0.2996494770050049 секунд
# 31/3000: =: tf.Tensor(1.7512196, shape=(), dtype=float32)
# Время эпохи 31 составляет 0.2832050323486328 секунд
# 32/3000: =: tf.Tensor(1.9247129, shape=(), dtype=float32)
# Время эпохи 32 составляет 0.2837538719177246 секунд
# 33/3000: =: tf.Tensor(1.7716397, shape=(), dtype=float32)
# Время эпохи 33 составляет 0.2664356231689453 секунд
# 34/3000: =: tf.Tensor(1.7501954, shape=(), dtype=float32)
# Время эпохи 34 составляет 0.2665560245513916 секунд
# 35/3000: =: tf.Tensor(1.7892007, shape=(), dtype=float32)
# Время эпохи 35 составляет 0.3005247116088867 секунд
# 36/3000: =: tf.Tensor(1.7116278, shape=(), dtype=float32)
# Время эпохи 36 составляет 0.3001065254211426 секунд
# 37/3000: =: tf.Tensor(1.7436285, shape=(), dtype=float32)
# Время эпохи 37 составляет 0.29537272453308105 секунд
# 38/3000: =: tf.Tensor(1.7293547, shape=(), dtype=float32)
# Время эпохи 38 составляет 0.23752903938293457 секунд
# 39/3000: =: tf.Tensor(1.7771932, shape=(), dtype=float32)
# Время эпохи 39 составляет 0.2665400505065918 секунд
# 40/3000: =: tf.Tensor(1.744784, shape=(), dtype=float32)
# Время эпохи 40 составляет 0.26676249504089355 секунд
# 41/3000: =: tf.Tensor(1.7204846, shape=(), dtype=float32)
# Время эпохи 41 составляет 0.25095176696777344 секунд
# 42/3000: =: tf.Tensor(1.762392, shape=(), dtype=float32)
# Время эпохи 42 составляет 0.2665586471557617 секунд
# 43/3000: =: tf.Tensor(1.7372122, shape=(), dtype=float32)
# Время эпохи 43 составляет 0.26600050926208496 секунд
# 44/3000: =: tf.Tensor(1.8255167, shape=(), dtype=float32)
# Время эпохи 44 составляет 0.2668781280517578 секунд
# 45/3000: =: tf.Tensor(1.7448953, shape=(), dtype=float32)
# Время эпохи 45 составляет 0.2665879726409912 секунд
# 46/3000: =: tf.Tensor(1.7214077, shape=(), dtype=float32)
# Время эпохи 46 составляет 0.267047643661499 секунд
# 47/3000: =: tf.Tensor(1.7279224, shape=(), dtype=float32)
# Время эпохи 47 составляет 0.34943199157714844 секунд
# 48/3000: =: tf.Tensor(1.7938479, shape=(), dtype=float32)
# Время эпохи 48 составляет 0.30060815811157227 секунд
# 49/3000: =: tf.Tensor(1.8302143, shape=(), dtype=float32)
# Время эпохи 49 составляет 0.2669227123260498 секунд
# 50/3000: =: tf.Tensor(1.7354567, shape=(), dtype=float32)
# Время эпохи 50 составляет 0.2656831741333008 секунд
# 51/3000: =: tf.Tensor(1.7872465, shape=(), dtype=float32)
# Время эпохи 51 составляет 0.2673017978668213 секунд
# 52/3000: =: tf.Tensor(1.611927, shape=(), dtype=float32)
# Время эпохи 52 составляет 0.350278377532959 секунд
# 53/3000: =: tf.Tensor(1.7396406, shape=(), dtype=float32)
# Время эпохи 53 составляет 0.29973411560058594 секунд
# 54/3000: =: tf.Tensor(1.7408435, shape=(), dtype=float32)
# Время эпохи 54 составляет 0.28278255462646484 секунд
# 55/3000: =: tf.Tensor(1.7712351, shape=(), dtype=float32)
# Время эпохи 55 составляет 0.26685094833374023 секунд
# 56/3000: =: tf.Tensor(1.7796175, shape=(), dtype=float32)
# Время эпохи 56 составляет 0.24998116493225098 секунд
# 57/3000: =: tf.Tensor(1.7350727, shape=(), dtype=float32)
# Время эпохи 57 составляет 0.30010032653808594 секунд
# 58/3000: =: tf.Tensor(1.772241, shape=(), dtype=float32)
# Время эпохи 58 составляет 0.3338310718536377 секунд
# 59/3000: =: tf.Tensor(1.828345, shape=(), dtype=float32)
# Время эпохи 59 составляет 0.30012989044189453 секунд
# 60/3000: =: tf.Tensor(1.7788461, shape=(), dtype=float32)
# Время эпохи 60 составляет 0.28290867805480957 секунд
# 61/3000: =: tf.Tensor(1.7439524, shape=(), dtype=float32)
# Время эпохи 61 составляет 0.2833259105682373 секунд
# 62/3000: =: tf.Tensor(1.7020781, shape=(), dtype=float32)
# Время эпохи 62 составляет 0.30040550231933594 секунд
# 63/3000: =: tf.Tensor(1.6832085, shape=(), dtype=float32)
# Время эпохи 63 составляет 0.29969191551208496 секунд
# 64/3000: =: tf.Tensor(1.8044561, shape=(), dtype=float32)
# Время эпохи 64 составляет 0.31653809547424316 секунд
# 65/3000: =: tf.Tensor(1.746965, shape=(), dtype=float32)
# Время эпохи 65 составляет 0.2896757125854492 секунд
# 66/3000: =: tf.Tensor(1.6972994, shape=(), dtype=float32)
# Время эпохи 66 составляет 0.28250741958618164 секунд
# 67/3000: =: tf.Tensor(1.6954663, shape=(), dtype=float32)
# Время эпохи 67 составляет 0.26686763763427734 секунд
# 68/3000: =: tf.Tensor(1.7246294, shape=(), dtype=float32)
# Время эпохи 68 составляет 0.2821199893951416 секунд
# 69/3000: =: tf.Tensor(1.7657002, shape=(), dtype=float32)
# Время эпохи 69 составляет 0.2965078353881836 секунд
# 70/3000: =: tf.Tensor(1.799015, shape=(), dtype=float32)
# Время эпохи 70 составляет 0.29320526123046875 секунд
# 71/3000: =: tf.Tensor(1.8096665, shape=(), dtype=float32)
# Время эпохи 71 составляет 0.2668888568878174 секунд
# 72/3000: =: tf.Tensor(1.7633084, shape=(), dtype=float32)
# Время эпохи 72 составляет 0.25080132484436035 секунд
# 73/3000: =: tf.Tensor(1.7367634, shape=(), dtype=float32)
# Время эпохи 73 составляет 0.30095911026000977 секунд
# 74/3000: =: tf.Tensor(1.7284049, shape=(), dtype=float32)
# Время эпохи 74 составляет 0.2800722122192383 секунд
# 75/3000: =: tf.Tensor(1.7204415, shape=(), dtype=float32)
# Время эпохи 75 составляет 0.26934242248535156 секунд
# 76/3000: =: tf.Tensor(1.8114859, shape=(), dtype=float32)
# Время эпохи 76 составляет 0.3042564392089844 секунд
# 77/3000: =: tf.Tensor(1.7027342, shape=(), dtype=float32)
# Время эпохи 77 составляет 0.2646825313568115 секунд
# 78/3000: =: tf.Tensor(1.6854131, shape=(), dtype=float32)
# Время эпохи 78 составляет 0.25084447860717773 секунд
# 79/3000: =: tf.Tensor(1.6768814, shape=(), dtype=float32)
# Время эпохи 79 составляет 0.27945613861083984 секунд
# 80/3000: =: tf.Tensor(1.6904093, shape=(), dtype=float32)
# Время эпохи 80 составляет 0.3056526184082031 секунд
# 81/3000: =: tf.Tensor(1.7488775, shape=(), dtype=float32)
# Время эпохи 81 составляет 0.2661442756652832 секунд
# 82/3000: =: tf.Tensor(1.7006291, shape=(), dtype=float32)
# Время эпохи 82 составляет 0.2998809814453125 секунд
# 83/3000: =: tf.Tensor(1.7486906, shape=(), dtype=float32)
# Время эпохи 83 составляет 0.3085010051727295 секунд
# 84/3000: =: tf.Tensor(1.8301976, shape=(), dtype=float32)
# Время эпохи 84 составляет 0.30059051513671875 секунд
# 85/3000: =: tf.Tensor(1.7142855, shape=(), dtype=float32)
# Время эпохи 85 составляет 0.313051700592041 секунд
# 86/3000: =: tf.Tensor(1.7241904, shape=(), dtype=float32)
# Время эпохи 86 составляет 0.2752995491027832 секунд
# 87/3000: =: tf.Tensor(1.6817995, shape=(), dtype=float32)
# Время эпохи 87 составляет 0.26704931259155273 секунд
# 88/3000: =: tf.Tensor(1.7513855, shape=(), dtype=float32)
# Время эпохи 88 составляет 0.2627854347229004 секунд
# 89/3000: =: tf.Tensor(1.7931118, shape=(), dtype=float32)
# Время эпохи 89 составляет 0.2815840244293213 секунд
# 90/3000: =: tf.Tensor(1.7589124, shape=(), dtype=float32)
# Время эпохи 90 составляет 0.2690744400024414 секунд
# 91/3000: =: tf.Tensor(1.7808769, shape=(), dtype=float32)
# Время эпохи 91 составляет 0.26239705085754395 секунд
# 92/3000: =: tf.Tensor(1.6434487, shape=(), dtype=float32)
# Время эпохи 92 составляет 0.34023261070251465 секунд
# 93/3000: =: tf.Tensor(1.7452418, shape=(), dtype=float32)
# Время эпохи 93 составляет 0.33188414573669434 секунд
# 94/3000: =: tf.Tensor(1.7746342, shape=(), dtype=float32)
# Время эпохи 94 составляет 0.31851983070373535 секунд
# 95/3000: =: tf.Tensor(1.7048925, shape=(), dtype=float32)
# Время эпохи 95 составляет 0.3137693405151367 секунд
# 96/3000: =: tf.Tensor(1.8220043, shape=(), dtype=float32)
# Время эпохи 96 составляет 0.294919490814209 секунд
# 97/3000: =: tf.Tensor(1.7244879, shape=(), dtype=float32)
# Время эпохи 97 составляет 0.31116223335266113 секунд
# 98/3000: =: tf.Tensor(1.7516565, shape=(), dtype=float32)
# Время эпохи 98 составляет 0.305858850479126 секунд
# 99/3000: =: tf.Tensor(1.7371284, shape=(), dtype=float32)
# Время эпохи 99 составляет 0.30613017082214355 секунд
# 100/3000: =: tf.Tensor(1.7046953, shape=(), dtype=float32)
# Время эпохи 100 составляет 0.30214619636535645 секунд
# 101/3000: =: tf.Tensor(1.7300011, shape=(), dtype=float32)
# Время эпохи 101 составляет 0.30944252014160156 секунд
# 102/3000: =: tf.Tensor(1.7529327, shape=(), dtype=float32)
# Время эпохи 102 составляет 0.3012878894805908 секунд
# 103/3000: =: tf.Tensor(1.7479715, shape=(), dtype=float32)
# Время эпохи 103 составляет 0.30893850326538086 секунд
# 104/3000: =: tf.Tensor(1.7346308, shape=(), dtype=float32)
# Время эпохи 104 составляет 0.30082225799560547 секунд
# 105/3000: =: tf.Tensor(1.7690294, shape=(), dtype=float32)
# Время эпохи 105 составляет 0.3044703006744385 секунд
# 106/3000: =: tf.Tensor(1.7822868, shape=(), dtype=float32)
# Время эпохи 106 составляет 0.3010578155517578 секунд
# 107/3000: =: tf.Tensor(1.6882694, shape=(), dtype=float32)
# Время эпохи 107 составляет 0.31201601028442383 секунд
# 108/3000: =: tf.Tensor(1.7519082, shape=(), dtype=float32)
# Время эпохи 108 составляет 0.3109250068664551 секунд
# 109/3000: =: tf.Tensor(1.7214943, shape=(), dtype=float32)
# Время эпохи 109 составляет 0.30263566970825195 секунд
# 110/3000: =: tf.Tensor(1.6890681, shape=(), dtype=float32)
# Время эпохи 110 составляет 0.298001766204834 секунд
# 111/3000: =: tf.Tensor(1.7592552, shape=(), dtype=float32)
# Время эпохи 111 составляет 0.3119931221008301 секунд
# 112/3000: =: tf.Tensor(1.7726015, shape=(), dtype=float32)
# Время эпохи 112 составляет 0.2850663661956787 секунд
# 113/3000: =: tf.Tensor(1.8012581, shape=(), dtype=float32)
# Время эпохи 113 составляет 0.26726531982421875 секунд
# 114/3000: =: tf.Tensor(1.775416, shape=(), dtype=float32)
# Время эпохи 114 составляет 0.2747457027435303 секунд
# 115/3000: =: tf.Tensor(1.7660972, shape=(), dtype=float32)
# Время эпохи 115 составляет 0.2805612087249756 секунд
# 116/3000: =: tf.Tensor(1.784233, shape=(), dtype=float32)
# Время эпохи 116 составляет 0.27211809158325195 секунд
# 117/3000: =: tf.Tensor(1.8036268, shape=(), dtype=float32)
# Время эпохи 117 составляет 0.27309703826904297 секунд
# 118/3000: =: tf.Tensor(1.7496125, shape=(), dtype=float32)
# Время эпохи 118 составляет 0.2658977508544922 секунд
# 119/3000: =: tf.Tensor(1.6943465, shape=(), dtype=float32)
# Время эпохи 119 составляет 0.2605874538421631 секунд
# 120/3000: =: tf.Tensor(1.7248136, shape=(), dtype=float32)
# Время эпохи 120 составляет 0.27506279945373535 секунд
# 121/3000: =: tf.Tensor(1.8223755, shape=(), dtype=float32)
# Время эпохи 121 составляет 0.2835819721221924 секунд
# 122/3000: =: tf.Tensor(1.7810819, shape=(), dtype=float32)
# Время эпохи 122 составляет 0.26556873321533203 секунд
# 123/3000: =: tf.Tensor(1.7301127, shape=(), dtype=float32)
# Время эпохи 123 составляет 0.26961183547973633 секунд
# 124/3000: =: tf.Tensor(1.6958656, shape=(), dtype=float32)
# Время эпохи 124 составляет 0.2610745429992676 секунд
# 125/3000: =: tf.Tensor(1.7291337, shape=(), dtype=float32)
# Время эпохи 125 составляет 0.2692584991455078 секунд
# 126/3000: =: tf.Tensor(1.8277601, shape=(), dtype=float32)
# Время эпохи 126 составляет 0.26857972145080566 секунд
# 127/3000: =: tf.Tensor(1.7371581, shape=(), dtype=float32)
# Время эпохи 127 составляет 0.2790689468383789 секунд
# 128/3000: =: tf.Tensor(1.6676301, shape=(), dtype=float32)
# Время эпохи 128 составляет 0.27948665618896484 секунд
# 129/3000: =: tf.Tensor(1.6945211, shape=(), dtype=float32)
# Время эпохи 129 составляет 0.3025815486907959 секунд
# 130/3000: =: tf.Tensor(1.7082998, shape=(), dtype=float32)
# Время эпохи 130 составляет 0.26430821418762207 секунд
# 131/3000: =: tf.Tensor(1.7629935, shape=(), dtype=float32)
# Время эпохи 131 составляет 0.2660861015319824 секунд
# 132/3000: =: tf.Tensor(1.7129748, shape=(), dtype=float32)
# Время эпохи 132 составляет 0.3061065673828125 секунд
# 133/3000: =: tf.Tensor(1.7691467, shape=(), dtype=float32)
# Время эпохи 133 составляет 0.3316054344177246 секунд
# 134/3000: =: tf.Tensor(1.7070024, shape=(), dtype=float32)
# Время эпохи 134 составляет 0.3225843906402588 секунд
# 135/3000: =: tf.Tensor(1.826331, shape=(), dtype=float32)
# Время эпохи 135 составляет 0.2936227321624756 секунд
# 136/3000: =: tf.Tensor(1.7377927, shape=(), dtype=float32)
# Время эпохи 136 составляет 0.2903273105621338 секунд
# 137/3000: =: tf.Tensor(1.713054, shape=(), dtype=float32)
# Время эпохи 137 составляет 0.2755601406097412 секунд
# 138/3000: =: tf.Tensor(1.6984787, shape=(), dtype=float32)
# Время эпохи 138 составляет 0.29120397567749023 секунд
# 139/3000: =: tf.Tensor(1.7109778, shape=(), dtype=float32)
# Время эпохи 139 составляет 0.32512974739074707 секунд
# 140/3000: =: tf.Tensor(1.8316393, shape=(), dtype=float32)
# Время эпохи 140 составляет 0.25557756423950195 секунд
# 141/3000: =: tf.Tensor(1.769995, shape=(), dtype=float32)
# Время эпохи 141 составляет 0.2730095386505127 секунд
# 142/3000: =: tf.Tensor(1.7814463, shape=(), dtype=float32)
# Время эпохи 142 составляет 0.2906205654144287 секунд
# 143/3000: =: tf.Tensor(1.7070849, shape=(), dtype=float32)
# Время эпохи 143 составляет 0.251096248626709 секунд
# 144/3000: =: tf.Tensor(1.7346935, shape=(), dtype=float32)
# Время эпохи 144 составляет 0.23873472213745117 секунд
# 145/3000: =: tf.Tensor(1.7532313, shape=(), dtype=float32)
# Время эпохи 145 составляет 0.2651045322418213 секунд
# 146/3000: =: tf.Tensor(1.8132924, shape=(), dtype=float32)
# Время эпохи 146 составляет 0.303131103515625 секунд
# 147/3000: =: tf.Tensor(1.7190053, shape=(), dtype=float32)
# Время эпохи 147 составляет 0.25000429153442383 секунд
# 148/3000: =: tf.Tensor(1.6841443, shape=(), dtype=float32)
# Время эпохи 148 составляет 0.3058202266693115 секунд
# 149/3000: =: tf.Tensor(1.743721, shape=(), dtype=float32)
# Время эпохи 149 составляет 0.31064438819885254 секунд
# 150/3000: =: tf.Tensor(1.7278947, shape=(), dtype=float32)
# Время эпохи 150 составляет 0.2816131114959717 секунд
# 151/3000: =: tf.Tensor(1.7176135, shape=(), dtype=float32)
# Время эпохи 151 составляет 0.2846207618713379 секунд
# 152/3000: =: tf.Tensor(1.7459453, shape=(), dtype=float32)
# Время эпохи 152 составляет 0.2765920162200928 секунд
# 153/3000: =: tf.Tensor(1.7473412, shape=(), dtype=float32)
# Время эпохи 153 составляет 0.2741200923919678 секунд
# 154/3000: =: tf.Tensor(1.7427874, shape=(), dtype=float32)
# Время эпохи 154 составляет 0.2916092872619629 секунд
# 155/3000: =: tf.Tensor(1.6758976, shape=(), dtype=float32)
# Время эпохи 155 составляет 0.2755851745605469 секунд
# 156/3000: =: tf.Tensor(1.787208, shape=(), dtype=float32)
# Время эпохи 156 составляет 0.2716257572174072 секунд
# 157/3000: =: tf.Tensor(1.7877408, shape=(), dtype=float32)
# Время эпохи 157 составляет 0.33903074264526367 секунд
# 158/3000: =: tf.Tensor(1.7800585, shape=(), dtype=float32)
# Время эпохи 158 составляет 0.31137514114379883 секунд
# 159/3000: =: tf.Tensor(1.8638055, shape=(), dtype=float32)
# Время эпохи 159 составляет 0.2825639247894287 секунд
# 160/3000: =: tf.Tensor(1.7645695, shape=(), dtype=float32)
# Время эпохи 160 составляет 0.34547853469848633 секунд
# 161/3000: =: tf.Tensor(1.7772894, shape=(), dtype=float32)
# Время эпохи 161 составляет 0.329470157623291 секунд
# 162/3000: =: tf.Tensor(1.6592027, shape=(), dtype=float32)
# Время эпохи 162 составляет 0.39231181144714355 секунд
# 163/3000: =: tf.Tensor(1.7235214, shape=(), dtype=float32)
# Время эпохи 163 составляет 0.31322360038757324 секунд
# 164/3000: =: tf.Tensor(1.6572592, shape=(), dtype=float32)
# Время эпохи 164 составляет 0.31382155418395996 секунд
# 165/3000: =: tf.Tensor(1.7588297, shape=(), dtype=float32)
# Время эпохи 165 составляет 0.34502243995666504 секунд
# 166/3000: =: tf.Tensor(1.7909735, shape=(), dtype=float32)
# Время эпохи 166 составляет 0.30818915367126465 секунд
# 167/3000: =: tf.Tensor(1.8697269, shape=(), dtype=float32)
# Время эпохи 167 составляет 0.319796085357666 секунд
# 168/3000: =: tf.Tensor(1.806471, shape=(), dtype=float32)
# Время эпохи 168 составляет 0.2508118152618408 секунд
# 169/3000: =: tf.Tensor(1.7556906, shape=(), dtype=float32)
# Время эпохи 169 составляет 0.26686739921569824 секунд
# 170/3000: =: tf.Tensor(1.7579498, shape=(), dtype=float32)
# Время эпохи 170 составляет 0.28252124786376953 секунд
# 171/3000: =: tf.Tensor(1.6677788, shape=(), dtype=float32)
# Время эпохи 171 составляет 0.2508072853088379 секунд
# 172/3000: =: tf.Tensor(1.7141502, shape=(), dtype=float32)
# Время эпохи 172 составляет 0.32202863693237305 секунд
# 173/3000: =: tf.Tensor(1.7094176, shape=(), dtype=float32)
# Время эпохи 173 составляет 0.3448050022125244 секунд
# 174/3000: =: tf.Tensor(1.7406769, shape=(), dtype=float32)
# Время эпохи 174 составляет 0.33359837532043457 секунд
# 175/3000: =: tf.Tensor(1.8070071, shape=(), dtype=float32)
# Время эпохи 175 составляет 0.3116152286529541 секунд
# 176/3000: =: tf.Tensor(1.751812, shape=(), dtype=float32)
# Время эпохи 176 составляет 0.3106551170349121 секунд
# 177/3000: =: tf.Tensor(1.7428216, shape=(), dtype=float32)
# Время эпохи 177 составляет 0.3055891990661621 секунд
# 178/3000: =: tf.Tensor(1.7657372, shape=(), dtype=float32)
# Время эпохи 178 составляет 0.31273674964904785 секунд
# 179/3000: =: tf.Tensor(1.7168272, shape=(), dtype=float32)
# Время эпохи 179 составляет 0.28122639656066895 секунд
# 180/3000: =: tf.Tensor(1.6682078, shape=(), dtype=float32)
# Время эпохи 180 составляет 0.26569342613220215 секунд
# 181/3000: =: tf.Tensor(1.7571837, shape=(), dtype=float32)
# Время эпохи 181 составляет 0.23493337631225586 секунд
# 182/3000: =: tf.Tensor(1.7602882, shape=(), dtype=float32)
# Время эпохи 182 составляет 0.24927735328674316 секунд
# 183/3000: =: tf.Tensor(1.7280623, shape=(), dtype=float32)
# Время эпохи 183 составляет 0.2501051425933838 секунд
# 184/3000: =: tf.Tensor(1.7110809, shape=(), dtype=float32)
# Время эпохи 184 составляет 0.250415563583374 секунд
# 185/3000: =: tf.Tensor(1.7025884, shape=(), dtype=float32)
# Время эпохи 185 составляет 0.24856162071228027 секунд
# 186/3000: =: tf.Tensor(1.7644055, shape=(), dtype=float32)
# Время эпохи 186 составляет 0.23450136184692383 секунд
# 187/3000: =: tf.Tensor(1.7864506, shape=(), dtype=float32)
# Время эпохи 187 составляет 0.2664923667907715 секунд
# 188/3000: =: tf.Tensor(1.6758162, shape=(), dtype=float32)
# Время эпохи 188 составляет 0.24986863136291504 секунд
# 189/3000: =: tf.Tensor(1.8486974, shape=(), dtype=float32)
# Время эпохи 189 составляет 0.25077152252197266 секунд
# 190/3000: =: tf.Tensor(1.7516683, shape=(), dtype=float32)
# Время эпохи 190 составляет 0.24980378150939941 секунд
# 191/3000: =: tf.Tensor(1.6788248, shape=(), dtype=float32)
# Время эпохи 191 составляет 0.2330024242401123 секунд
# 192/3000: =: tf.Tensor(1.7611046, shape=(), dtype=float32)
# Время эпохи 192 составляет 0.2475261688232422 секунд
# 193/3000: =: tf.Tensor(1.8130522, shape=(), dtype=float32)
# Время эпохи 193 составляет 0.2508430480957031 секунд
# 194/3000: =: tf.Tensor(1.7259442, shape=(), dtype=float32)
# Время эпохи 194 составляет 0.26694607734680176 секунд
# 195/3000: =: tf.Tensor(1.7654445, shape=(), dtype=float32)
# Время эпохи 195 составляет 0.2513294219970703 секунд
# 196/3000: =: tf.Tensor(1.8101875, shape=(), dtype=float32)
# Время эпохи 196 составляет 0.2663414478302002 секунд
# 197/3000: =: tf.Tensor(1.7752177, shape=(), dtype=float32)
# Время эпохи 197 составляет 0.2512376308441162 секунд
# 198/3000: =: tf.Tensor(1.720128, shape=(), dtype=float32)
# Время эпохи 198 составляет 0.23521876335144043 секунд
# 199/3000: =: tf.Tensor(1.7515829, shape=(), dtype=float32)
# Время эпохи 199 составляет 0.2512247562408447 секунд
# 200/3000: =: tf.Tensor(1.719417, shape=(), dtype=float32)
# Время эпохи 200 составляет 0.2509028911590576 секунд
# 201/3000: =: tf.Tensor(1.7995052, shape=(), dtype=float32)
# Время эпохи 201 составляет 0.25121331214904785 секунд
# 202/3000: =: tf.Tensor(1.7564919, shape=(), dtype=float32)
# Время эпохи 202 составляет 0.26645517349243164 секунд
# 203/3000: =: tf.Tensor(1.7437032, shape=(), dtype=float32)
# Время эпохи 203 составляет 0.25073885917663574 секунд
# 204/3000: =: tf.Tensor(1.7449691, shape=(), dtype=float32)
# Время эпохи 204 составляет 0.2508070468902588 секунд
# 205/3000: =: tf.Tensor(1.7511051, shape=(), dtype=float32)
# Время эпохи 205 составляет 0.2512350082397461 секунд
# 206/3000: =: tf.Tensor(1.8166147, shape=(), dtype=float32)
# Время эпохи 206 составляет 0.25084972381591797 секунд
# 207/3000: =: tf.Tensor(1.7435634, shape=(), dtype=float32)
# Время эпохи 207 составляет 0.2512638568878174 секунд
# 208/3000: =: tf.Tensor(1.7324773, shape=(), dtype=float32)
# Время эпохи 208 составляет 0.2508363723754883 секунд
# 209/3000: =: tf.Tensor(1.7488235, shape=(), dtype=float32)
# Время эпохи 209 составляет 0.2512526512145996 секунд
# 210/3000: =: tf.Tensor(1.7802097, shape=(), dtype=float32)
# Время эпохи 210 составляет 0.2346963882446289 секунд
# 211/3000: =: tf.Tensor(1.8163768, shape=(), dtype=float32)
# Время эпохи 211 составляет 0.251237154006958 секунд
# 212/3000: =: tf.Tensor(1.7320317, shape=(), dtype=float32)
# Время эпохи 212 составляет 0.25084996223449707 секунд
# 213/3000: =: tf.Tensor(1.8055793, shape=(), dtype=float32)
# Время эпохи 213 составляет 0.25123143196105957 секунд
# 214/3000: =: tf.Tensor(1.7176007, shape=(), dtype=float32)
# Время эпохи 214 составляет 0.250870943069458 секунд
# 215/3000: =: tf.Tensor(1.7353715, shape=(), dtype=float32)
# Время эпохи 215 составляет 0.2512319087982178 секунд
# 216/3000: =: tf.Tensor(1.748285, shape=(), dtype=float32)
# Время эпохи 216 составляет 0.25086355209350586 секунд
# 217/3000: =: tf.Tensor(1.7036501, shape=(), dtype=float32)
# Время эпохи 217 составляет 0.24118685722351074 секунд
# 218/3000: =: tf.Tensor(1.6594361, shape=(), dtype=float32)
# Время эпохи 218 составляет 0.24472951889038086 секунд
# 219/3000: =: tf.Tensor(1.8497559, shape=(), dtype=float32)
# Время эпохи 219 составляет 0.26688480377197266 секунд
# 220/3000: =: tf.Tensor(1.8057623, shape=(), dtype=float32)
# Время эпохи 220 составляет 0.2508516311645508 секунд
# 221/3000: =: tf.Tensor(1.7823039, shape=(), dtype=float32)
# Время эпохи 221 составляет 0.25126147270202637 секунд
# 222/3000: =: tf.Tensor(1.6964666, shape=(), dtype=float32)
# Время эпохи 222 составляет 0.2508368492126465 секунд
# 223/3000: =: tf.Tensor(1.7596052, shape=(), dtype=float32)
# Время эпохи 223 составляет 0.23876023292541504 секунд
# 224/3000: =: tf.Tensor(1.8445104, shape=(), dtype=float32)
# Время эпохи 224 составляет 0.2628600597381592 секунд
# 225/3000: =: tf.Tensor(1.7129887, shape=(), dtype=float32)
# Время эпохи 225 составляет 0.2382347583770752 секунд
# 226/3000: =: tf.Tensor(1.7582667, shape=(), dtype=float32)
# Время эпохи 226 составляет 0.24825692176818848 секунд
# 227/3000: =: tf.Tensor(1.7792861, shape=(), dtype=float32)
# Время эпохи 227 составляет 0.2528421878814697 секунд
# 228/3000: =: tf.Tensor(1.7417698, shape=(), dtype=float32)
# Время эпохи 228 составляет 0.2492830753326416 секунд
# 229/3000: =: tf.Tensor(1.7816902, shape=(), dtype=float32)
# Время эпохи 229 составляет 0.2518131732940674 секунд
# 230/3000: =: tf.Tensor(1.7022936, shape=(), dtype=float32)
# Время эпохи 230 составляет 0.2346193790435791 секунд
# 231/3000: =: tf.Tensor(1.7018776, shape=(), dtype=float32)
# Время эпохи 231 составляет 0.25082874298095703 секунд
# 232/3000: =: tf.Tensor(1.8251755, shape=(), dtype=float32)
# Время эпохи 232 составляет 0.25076770782470703 секунд
# 233/3000: =: tf.Tensor(1.7893745, shape=(), dtype=float32)
# Время эпохи 233 составляет 0.2508401870727539 секунд
# 234/3000: =: tf.Tensor(1.6421878, shape=(), dtype=float32)
# Время эпохи 234 составляет 0.25125885009765625 секунд
# 235/3000: =: tf.Tensor(1.7370147, shape=(), dtype=float32)
# Время эпохи 235 составляет 0.25081849098205566 секунд
# 236/3000: =: tf.Tensor(1.8054543, shape=(), dtype=float32)
# Время эпохи 236 составляет 0.25124287605285645 секунд
# 237/3000: =: tf.Tensor(1.7745317, shape=(), dtype=float32)
# Время эпохи 237 составляет 0.2508678436279297 секунд
# 238/3000: =: tf.Tensor(1.781896, shape=(), dtype=float32)
# Время эпохи 238 составляет 0.23602843284606934 секунд
# 239/3000: =: tf.Tensor(1.8462826, shape=(), dtype=float32)
# Время эпохи 239 составляет 0.2508351802825928 секунд
# 240/3000: =: tf.Tensor(1.718565, shape=(), dtype=float32)
# Время эпохи 240 составляет 0.2512857913970947 секунд
# 241/3000: =: tf.Tensor(1.7548081, shape=(), dtype=float32)
# Время эпохи 241 составляет 0.2765316963195801 секунд
# 242/3000: =: tf.Tensor(1.7315172, shape=(), dtype=float32)
# Время эпохи 242 составляет 0.2412428855895996 секунд
# 243/3000: =: tf.Tensor(1.7509354, shape=(), dtype=float32)
# Время эпохи 243 составляет 0.2508208751678467 секунд
# 244/3000: =: tf.Tensor(1.7949733, shape=(), dtype=float32)
# Время эпохи 244 составляет 0.2512788772583008 секунд
# 245/3000: =: tf.Tensor(1.7314774, shape=(), dtype=float32)
# Время эпохи 245 составляет 0.2508583068847656 секунд
# 246/3000: =: tf.Tensor(1.747264, shape=(), dtype=float32)
# Время эпохи 246 составляет 0.2356245517730713 секунд
# 247/3000: =: tf.Tensor(1.7836543, shape=(), dtype=float32)
# Время эпохи 247 составляет 0.2508385181427002 секунд
# 248/3000: =: tf.Tensor(1.871585, shape=(), dtype=float32)
# Время эпохи 248 составляет 0.25128173828125 секунд
# 249/3000: =: tf.Tensor(1.7495612, shape=(), dtype=float32)
# Время эпохи 249 составляет 0.25081944465637207 секунд
# 250/3000: =: tf.Tensor(1.7645415, shape=(), dtype=float32)
# Время эпохи 250 составляет 0.2512516975402832 секунд
# 251/3000: =: tf.Tensor(1.7920555, shape=(), dtype=float32)
# Время эпохи 251 составляет 0.25080037117004395 секунд
# 252/3000: =: tf.Tensor(1.7587054, shape=(), dtype=float32)
# Время эпохи 252 составляет 0.25121450424194336 секунд
# 253/3000: =: tf.Tensor(1.7354434, shape=(), dtype=float32)
# Время эпохи 253 составляет 0.23520135879516602 секунд
# 254/3000: =: tf.Tensor(1.7479161, shape=(), dtype=float32)
# Время эпохи 254 составляет 0.250744104385376 секунд
# 255/3000: =: tf.Tensor(1.7796105, shape=(), dtype=float32)
# Время эпохи 255 составляет 0.2507960796356201 секунд
# 256/3000: =: tf.Tensor(1.8435944, shape=(), dtype=float32)
# Время эпохи 256 составляет 0.2512483596801758 секунд
# 257/3000: =: tf.Tensor(1.8058068, shape=(), dtype=float32)
# Время эпохи 257 составляет 0.250835657119751 секунд
# 258/3000: =: tf.Tensor(1.7689732, shape=(), dtype=float32)
# Время эпохи 258 составляет 0.23564624786376953 секунд
# 259/3000: =: tf.Tensor(1.8126364, shape=(), dtype=float32)
# Время эпохи 259 составляет 0.2512378692626953 секунд
# 260/3000: =: tf.Tensor(1.7130364, shape=(), dtype=float32)
# Время эпохи 260 составляет 0.25123071670532227 секунд
# 261/3000: =: tf.Tensor(1.7396135, shape=(), dtype=float32)
# Время эпохи 261 составляет 0.26653051376342773 секунд
# 262/3000: =: tf.Tensor(1.7697232, shape=(), dtype=float32)
# Время эпохи 262 составляет 0.25127315521240234 секунд
# 263/3000: =: tf.Tensor(1.7755375, shape=(), dtype=float32)
# Время эпохи 263 составляет 0.2508225440979004 секунд
# 264/3000: =: tf.Tensor(1.7492533, shape=(), dtype=float32)
# Время эпохи 264 составляет 0.251239538192749 секунд
# 265/3000: =: tf.Tensor(1.6748836, shape=(), dtype=float32)
# Время эпохи 265 составляет 0.25080037117004395 секунд
# 266/3000: =: tf.Tensor(1.7346694, shape=(), dtype=float32)
# Время эпохи 266 составляет 0.23563623428344727 секунд
# 267/3000: =: tf.Tensor(1.7603054, shape=(), dtype=float32)
# Время эпохи 267 составляет 0.2503628730773926 секунд
# 268/3000: =: tf.Tensor(1.7753401, shape=(), dtype=float32)
# Время эпохи 268 составляет 0.2512381076812744 секунд
# 269/3000: =: tf.Tensor(1.7259982, shape=(), dtype=float32)
# Время эпохи 269 составляет 0.2508270740509033 секунд
# 270/3000: =: tf.Tensor(1.7669204, shape=(), dtype=float32)
# Время эпохи 270 составляет 0.2512552738189697 секунд
# 271/3000: =: tf.Tensor(1.7810376, shape=(), dtype=float32)
# Время эпохи 271 составляет 0.2508277893066406 секунд
# 272/3000: =: tf.Tensor(1.7865856, shape=(), dtype=float32)
# Время эпохи 272 составляет 0.2512500286102295 секунд
# 273/3000: =: tf.Tensor(1.780278, shape=(), dtype=float32)
# Время эпохи 273 составляет 0.2508530616760254 секунд
# 274/3000: =: tf.Tensor(1.7750356, shape=(), dtype=float32)
# Время эпохи 274 составляет 0.2512228488922119 секунд
# 275/3000: =: tf.Tensor(1.783141, shape=(), dtype=float32)
# Время эпохи 275 составляет 0.25084757804870605 секунд
# 276/3000: =: tf.Tensor(1.7631823, shape=(), dtype=float32)
# Время эпохи 276 составляет 0.239732027053833 секунд
# 277/3000: =: tf.Tensor(1.7521261, shape=(), dtype=float32)
# Время эпохи 277 составляет 0.24675941467285156 секунд
# 278/3000: =: tf.Tensor(1.7693623, shape=(), dtype=float32)
# Время эпохи 278 составляет 0.2543487548828125 секунд
# 279/3000: =: tf.Tensor(1.701492, shape=(), dtype=float32)
# Время эпохи 279 составляет 0.24721336364746094 секунд
# 280/3000: =: tf.Tensor(1.701421, shape=(), dtype=float32)
# Время эпохи 280 составляет 0.2669062614440918 секунд
# 281/3000: =: tf.Tensor(1.7985812, shape=(), dtype=float32)
# Время эпохи 281 составляет 0.2508375644683838 секунд
# 282/3000: =: tf.Tensor(1.7659849, shape=(), dtype=float32)
# Время эпохи 282 составляет 0.25121450424194336 секунд
# 283/3000: =: tf.Tensor(1.7703431, shape=(), dtype=float32)
# Время эпохи 283 составляет 0.2508556842803955 секунд
# 284/3000: =: tf.Tensor(1.8410776, shape=(), dtype=float32)
# Время эпохи 284 составляет 0.2512998580932617 секунд
# 285/3000: =: tf.Tensor(1.7414253, shape=(), dtype=float32)
# Время эпохи 285 составляет 0.2508525848388672 секунд
# 286/3000: =: tf.Tensor(1.819929, shape=(), dtype=float32)
# Время эпохи 286 составляет 0.2356562614440918 секунд
# 287/3000: =: tf.Tensor(1.778389, shape=(), dtype=float32)
# Время эпохи 287 составляет 0.25087976455688477 секунд
# 288/3000: =: tf.Tensor(1.80149, shape=(), dtype=float32)
# Время эпохи 288 составляет 0.2512378692626953 секунд
# 289/3000: =: tf.Tensor(1.7036489, shape=(), dtype=float32)
# Время эпохи 289 составляет 0.2664968967437744 секунд
# 290/3000: =: tf.Tensor(1.8120321, shape=(), dtype=float32)
# Время эпохи 290 составляет 0.25122785568237305 секунд
# 291/3000: =: tf.Tensor(1.8278126, shape=(), dtype=float32)
# Время эпохи 291 составляет 0.23519253730773926 секунд
# 292/3000: =: tf.Tensor(1.7490417, shape=(), dtype=float32)
# Время эпохи 292 составляет 0.25070738792419434 секунд
# 293/3000: =: tf.Tensor(1.7862765, shape=(), dtype=float32)
# Время эпохи 293 составляет 0.250866174697876 секунд
# 294/3000: =: tf.Tensor(1.7446012, shape=(), dtype=float32)
# Время эпохи 294 составляет 0.2512190341949463 секунд
# 295/3000: =: tf.Tensor(1.8063109, shape=(), dtype=float32)
# Время эпохи 295 составляет 0.25083327293395996 секунд
# 296/3000: =: tf.Tensor(1.7083066, shape=(), dtype=float32)
# Время эпохи 296 составляет 0.2513113021850586 секунд
# 297/3000: =: tf.Tensor(1.7052374, shape=(), dtype=float32)
# Время эпохи 297 составляет 0.25084519386291504 секунд
# 298/3000: =: tf.Tensor(1.7273729, shape=(), dtype=float32)
# Время эпохи 298 составляет 0.24470901489257812 секунд
# 299/3000: =: tf.Tensor(1.7571647, shape=(), dtype=float32)
# Время эпохи 299 составляет 0.24325037002563477 секунд
# 300/3000: =: tf.Tensor(1.7079283, shape=(), dtype=float32)
# Время эпохи 300 составляет 0.26531481742858887 секунд
# 301/3000: =: tf.Tensor(1.7972571, shape=(), dtype=float32)
# Время эпохи 301 составляет 0.250821590423584 секунд
# 302/3000: =: tf.Tensor(1.7971699, shape=(), dtype=float32)
# Время эпохи 302 составляет 0.25123143196105957 секунд
# 303/3000: =: tf.Tensor(1.755864, shape=(), dtype=float32)
# Время эпохи 303 составляет 0.2508411407470703 секунд
# 304/3000: =: tf.Tensor(1.7838215, shape=(), dtype=float32)
# Время эпохи 304 составляет 0.2512378692626953 секунд
# 305/3000: =: tf.Tensor(1.8860245, shape=(), dtype=float32)
# Время эпохи 305 составляет 0.2508997917175293 секунд
# 306/3000: =: tf.Tensor(1.8170437, shape=(), dtype=float32)
# Время эпохи 306 составляет 0.24071359634399414 секунд
# 307/3000: =: tf.Tensor(1.8033913, shape=(), dtype=float32)
# Время эпохи 307 составляет 0.24573230743408203 секунд
# 308/3000: =: tf.Tensor(1.6663144, shape=(), dtype=float32)
# Время эпохи 308 составляет 0.25083017349243164 секунд
# 309/3000: =: tf.Tensor(1.7899331, shape=(), dtype=float32)
# Время эпохи 309 составляет 0.23561906814575195 секунд
# 310/3000: =: tf.Tensor(1.816069, shape=(), dtype=float32)
# Время эпохи 310 составляет 0.25081944465637207 секунд
# 311/3000: =: tf.Tensor(1.7333668, shape=(), dtype=float32)
# Время эпохи 311 составляет 0.2507190704345703 секунд
# 312/3000: =: tf.Tensor(1.6945463, shape=(), dtype=float32)
# Время эпохи 312 составляет 0.25081682205200195 секунд
# 313/3000: =: tf.Tensor(1.8370448, shape=(), dtype=float32)
# Время эпохи 313 составляет 0.23563694953918457 секунд
# 314/3000: =: tf.Tensor(1.7501296, shape=(), dtype=float32)
# Время эпохи 314 составляет 0.2508094310760498 секунд
# 315/3000: =: tf.Tensor(1.8088824, shape=(), dtype=float32)
# Время эпохи 315 составляет 0.25121521949768066 секунд
# 316/3000: =: tf.Tensor(1.8627234, shape=(), dtype=float32)
# Время эпохи 316 составляет 0.2508084774017334 секунд
# 317/3000: =: tf.Tensor(1.7972025, shape=(), dtype=float32)
# Время эпохи 317 составляет 0.26689863204956055 секунд
# 318/3000: =: tf.Tensor(1.78559, shape=(), dtype=float32)
# Время эпохи 318 составляет 0.2508223056793213 секунд
# 319/3000: =: tf.Tensor(1.7320607, shape=(), dtype=float32)
# Время эпохи 319 составляет 0.25070786476135254 секунд
# 320/3000: =: tf.Tensor(1.8001453, shape=(), dtype=float32)
# Время эпохи 320 составляет 0.25082921981811523 секунд
# 321/3000: =: tf.Tensor(1.7832854, shape=(), dtype=float32)
# Время эпохи 321 составляет 0.2512495517730713 секунд
# 322/3000: =: tf.Tensor(1.782985, shape=(), dtype=float32)
# Время эпохи 322 составляет 0.23518967628479004 секунд
# 323/3000: =: tf.Tensor(1.7629489, shape=(), dtype=float32)
# Время эпохи 323 составляет 0.25126051902770996 секунд
# 324/3000: =: tf.Tensor(1.7860849, shape=(), dtype=float32)
# Время эпохи 324 составляет 0.25081801414489746 секунд
# 325/3000: =: tf.Tensor(1.725506, shape=(), dtype=float32)
# Время эпохи 325 составляет 0.25121593475341797 секунд
# 326/3000: =: tf.Tensor(1.8138926, shape=(), dtype=float32)
# Время эпохи 326 составляет 0.2503049373626709 секунд
# 327/3000: =: tf.Tensor(1.8127304, shape=(), dtype=float32)
# Время эпохи 327 составляет 0.2512497901916504 секунд
# 328/3000: =: tf.Tensor(1.7670813, shape=(), dtype=float32)
# Время эпохи 328 составляет 0.25081801414489746 секунд
# 329/3000: =: tf.Tensor(1.7295268, shape=(), dtype=float32)
# Время эпохи 329 составляет 0.23563432693481445 секунд
# 330/3000: =: tf.Tensor(1.7219044, shape=(), dtype=float32)
# Время эпохи 330 составляет 0.2508280277252197 секунд
# 331/3000: =: tf.Tensor(1.7182038, shape=(), dtype=float32)
# Время эпохи 331 составляет 0.25123000144958496 секунд
# 332/3000: =: tf.Tensor(1.8131162, shape=(), dtype=float32)
# Время эпохи 332 составляет 0.25086498260498047 секунд
# 333/3000: =: tf.Tensor(1.7645322, shape=(), dtype=float32)
# Время эпохи 333 составляет 0.2664165496826172 секунд
# 334/3000: =: tf.Tensor(1.7466605, shape=(), dtype=float32)
# Время эпохи 334 составляет 0.250826358795166 секунд
# 335/3000: =: tf.Tensor(1.7820625, shape=(), dtype=float32)
# Время эпохи 335 составляет 0.2512688636779785 секунд
# 336/3000: =: tf.Tensor(1.8085254, shape=(), dtype=float32)
# Время эпохи 336 составляет 0.2509036064147949 секунд
# 337/3000: =: tf.Tensor(1.7946231, shape=(), dtype=float32)
# Время эпохи 337 составляет 0.2669398784637451 секунд
# 338/3000: =: tf.Tensor(1.7502941, shape=(), dtype=float32)
# Время эпохи 338 составляет 0.2669081687927246 секунд
# 339/3000: =: tf.Tensor(1.8063616, shape=(), dtype=float32)
# Время эпохи 339 составляет 0.26648640632629395 секунд
# 340/3000: =: tf.Tensor(1.7927535, shape=(), dtype=float32)
# Время эпохи 340 составляет 0.25126171112060547 секунд
# 341/3000: =: tf.Tensor(1.7603037, shape=(), dtype=float32)
# Время эпохи 341 составляет 0.2351999282836914 секунд
# 342/3000: =: tf.Tensor(1.8378675, shape=(), dtype=float32)
# Время эпохи 342 составляет 0.25121116638183594 секунд
# 343/3000: =: tf.Tensor(1.7072378, shape=(), dtype=float32)
# Время эпохи 343 составляет 0.23522329330444336 секунд
# 344/3000: =: tf.Tensor(1.774448, shape=(), dtype=float32)
# Время эпохи 344 составляет 0.2543039321899414 секунд
# 345/3000: =: tf.Tensor(1.784547, shape=(), dtype=float32)
# Время эпохи 345 составляет 0.2628512382507324 секунд
# 346/3000: =: tf.Tensor(1.6888463, shape=(), dtype=float32)
# Время эпохи 346 составляет 0.266890287399292 секунд
# 347/3000: =: tf.Tensor(1.8527216, shape=(), dtype=float32)
# Время эпохи 347 составляет 0.2664663791656494 секунд
# 348/3000: =: tf.Tensor(1.7645639, shape=(), dtype=float32)
# Время эпохи 348 составляет 0.2669811248779297 секунд
# 349/3000: =: tf.Tensor(1.7678154, shape=(), dtype=float32)
# Время эпохи 349 составляет 0.2669029235839844 секунд
# 350/3000: =: tf.Tensor(1.7391516, shape=(), dtype=float32)
# Время эпохи 350 составляет 0.2734651565551758 секунд
# 351/3000: =: tf.Tensor(1.7616285, shape=(), dtype=float32)
# Время эпохи 351 составляет 0.2442324161529541 секунд
# 352/3000: =: tf.Tensor(1.8291811, shape=(), dtype=float32)
# Время эпохи 352 составляет 0.2568397521972656 секунд
# 353/3000: =: tf.Tensor(1.8329698, shape=(), dtype=float32)
# Время эпохи 353 составляет 0.2447524070739746 секунд
# 354/3000: =: tf.Tensor(1.7262495, shape=(), dtype=float32)
# Время эпохи 354 составляет 0.25123047828674316 секунд
# 355/3000: =: tf.Tensor(1.7677346, shape=(), dtype=float32)
# Время эпохи 355 составляет 0.2512390613555908 секунд
# 356/3000: =: tf.Tensor(1.7472484, shape=(), dtype=float32)
# Время эпохи 356 составляет 0.25434136390686035 секунд
# 357/3000: =: tf.Tensor(1.8389207, shape=(), dtype=float32)
# Время эпохи 357 составляет 0.24723172187805176 секунд
# 358/3000: =: tf.Tensor(1.784973, shape=(), dtype=float32)
# Время эпохи 358 составляет 0.2352132797241211 секунд
# 359/3000: =: tf.Tensor(1.7687874, shape=(), dtype=float32)
# Время эпохи 359 составляет 0.25128912925720215 секунд
# 360/3000: =: tf.Tensor(1.7828401, shape=(), dtype=float32)
# Время эпохи 360 составляет 0.2504305839538574 секунд
# 361/3000: =: tf.Tensor(1.7095983, shape=(), dtype=float32)
# Время эпохи 361 составляет 0.2512080669403076 секунд
# 362/3000: =: tf.Tensor(1.7003918, shape=(), dtype=float32)
# Время эпохи 362 составляет 0.2351856231689453 секунд
# 363/3000: =: tf.Tensor(1.7697008, shape=(), dtype=float32)
# Время эпохи 363 составляет 0.25128865242004395 секунд
# 364/3000: =: tf.Tensor(1.7830402, shape=(), dtype=float32)
# Время эпохи 364 составляет 0.26645684242248535 секунд
# 365/3000: =: tf.Tensor(1.785723, shape=(), dtype=float32)
# Время эпохи 365 составляет 0.2356410026550293 секунд
# 366/3000: =: tf.Tensor(1.7321273, shape=(), dtype=float32)
# Время эпохи 366 составляет 0.2664823532104492 секунд
# 367/3000: =: tf.Tensor(1.7019361, shape=(), dtype=float32)
# Время эпохи 367 составляет 0.25124382972717285 секунд
# 368/3000: =: tf.Tensor(1.8036497, shape=(), dtype=float32)
# Время эпохи 368 составляет 0.250852108001709 секунд
# 369/3000: =: tf.Tensor(1.8059963, shape=(), dtype=float32)
# Время эпохи 369 составляет 0.2512075901031494 секунд
# 370/3000: =: tf.Tensor(1.7772496, shape=(), dtype=float32)
# Время эпохи 370 составляет 0.2508425712585449 секунд
# 371/3000: =: tf.Tensor(1.7524866, shape=(), dtype=float32)
# Время эпохи 371 составляет 0.2356259822845459 секунд
# 372/3000: =: tf.Tensor(1.844577, shape=(), dtype=float32)
# Время эпохи 372 составляет 0.2503199577331543 секунд
# 373/3000: =: tf.Tensor(1.8093795, shape=(), dtype=float32)
# Время эпохи 373 составляет 0.2512776851654053 секунд
# 374/3000: =: tf.Tensor(1.7662336, shape=(), dtype=float32)
# Время эпохи 374 составляет 0.2508254051208496 секунд
# 375/3000: =: tf.Tensor(1.7447914, shape=(), dtype=float32)
# Время эпохи 375 составляет 0.25124645233154297 секунд
# 376/3000: =: tf.Tensor(1.7559106, shape=(), dtype=float32)
# Время эпохи 376 составляет 0.25083327293395996 секунд
# 377/3000: =: tf.Tensor(1.7546979, shape=(), dtype=float32)
# Время эпохи 377 составляет 0.23562240600585938 секунд
# 378/3000: =: tf.Tensor(1.7153549, shape=(), dtype=float32)
# Время эпохи 378 составляет 0.2508389949798584 секунд
# 379/3000: =: tf.Tensor(1.7549075, shape=(), dtype=float32)
# Время эпохи 379 составляет 0.2668933868408203 секунд
# 380/3000: =: tf.Tensor(1.739415, shape=(), dtype=float32)
# Время эпохи 380 составляет 0.26651716232299805 секунд
# 381/3000: =: tf.Tensor(1.7420851, shape=(), dtype=float32)
# Время эпохи 381 составляет 0.2512319087982178 секунд
# 382/3000: =: tf.Tensor(1.8381917, shape=(), dtype=float32)
# Время эпохи 382 составляет 0.25081419944763184 секунд
# 383/3000: =: tf.Tensor(1.8320929, shape=(), dtype=float32)
# Время эпохи 383 составляет 0.23558974266052246 секунд
# 384/3000: =: tf.Tensor(1.7953385, shape=(), dtype=float32)
# Время эпохи 384 составляет 0.25085902214050293 секунд
# 385/3000: =: tf.Tensor(1.7680595, shape=(), dtype=float32)
# Время эпохи 385 составляет 0.25120997428894043 секунд
# 386/3000: =: tf.Tensor(1.8241004, shape=(), dtype=float32)
# Время эпохи 386 составляет 0.2508409023284912 секунд
# 387/3000: =: tf.Tensor(1.8926865, shape=(), dtype=float32)
# Время эпохи 387 составляет 0.2512960433959961 секунд
# 388/3000: =: tf.Tensor(1.8475507, shape=(), dtype=float32)
# Время эпохи 388 составляет 0.2508063316345215 секунд
# 389/3000: =: tf.Tensor(1.8143986, shape=(), dtype=float32)
# Время эпохи 389 составляет 0.25166893005371094 секунд
# 390/3000: =: tf.Tensor(1.8289009, shape=(), dtype=float32)
# Время эпохи 390 составляет 0.23520684242248535 секунд
# 391/3000: =: tf.Tensor(1.7031838, shape=(), dtype=float32)
# Время эпохи 391 составляет 0.2512483596801758 секунд
# 392/3000: =: tf.Tensor(1.7390375, shape=(), dtype=float32)
# Время эпохи 392 составляет 0.25081539154052734 секунд
# 393/3000: =: tf.Tensor(1.7784255, shape=(), dtype=float32)
# Время эпохи 393 составляет 0.2668945789337158 секунд
# 394/3000: =: tf.Tensor(1.764547, shape=(), dtype=float32)
# Время эпохи 394 составляет 0.2663431167602539 секунд
# 395/3000: =: tf.Tensor(1.7539008, shape=(), dtype=float32)
# Время эпохи 395 составляет 0.23520565032958984 секунд
# 396/3000: =: tf.Tensor(1.8362617, shape=(), dtype=float32)
# Время эпохи 396 составляет 0.2658650875091553 секунд
# 397/3000: =: tf.Tensor(1.7643813, shape=(), dtype=float32)
# Время эпохи 397 составляет 0.23620820045471191 секунд
# 398/3000: =: tf.Tensor(1.8632423, shape=(), dtype=float32)
# Время эпохи 398 составляет 0.25081682205200195 секунд
# 399/3000: =: tf.Tensor(1.7038374, shape=(), dtype=float32)
# Время эпохи 399 составляет 0.2512176036834717 секунд
# 400/3000: =: tf.Tensor(1.7827064, shape=(), dtype=float32)
# Время эпохи 400 составляет 0.250826358795166 секунд
# 401/3000: =: tf.Tensor(1.7645768, shape=(), dtype=float32)
# Время эпохи 401 составляет 0.25123071670532227 секунд
# 402/3000: =: tf.Tensor(1.7148215, shape=(), dtype=float32)
# Время эпохи 402 составляет 0.23470306396484375 секунд
# 403/3000: =: tf.Tensor(1.8374426, shape=(), dtype=float32)
# Время эпохи 403 составляет 0.2512357234954834 секунд
# 404/3000: =: tf.Tensor(1.8241913, shape=(), dtype=float32)
# Время эпохи 404 составляет 0.25081944465637207 секунд
# 405/3000: =: tf.Tensor(1.7794998, shape=(), dtype=float32)
# Время эпохи 405 составляет 0.2512986660003662 секунд
# 406/3000: =: tf.Tensor(1.7353369, shape=(), dtype=float32)
# Время эпохи 406 составляет 0.2665138244628906 секунд
# 407/3000: =: tf.Tensor(1.8082049, shape=(), dtype=float32)
# Время эпохи 407 составляет 0.25123047828674316 секунд
# 408/3000: =: tf.Tensor(1.8327187, shape=(), dtype=float32)
# Время эпохи 408 составляет 0.26035284996032715 секунд
# 409/3000: =: tf.Tensor(1.7587255, shape=(), dtype=float32)
# Время эпохи 409 составляет 0.2412567138671875 секунд
# 410/3000: =: tf.Tensor(1.6659638, shape=(), dtype=float32)
# Время эпохи 410 составляет 0.2508096694946289 секунд
# 411/3000: =: tf.Tensor(1.7241377, shape=(), dtype=float32)
# Время эпохи 411 составляет 0.25121307373046875 секунд
# 412/3000: =: tf.Tensor(1.8142827, shape=(), dtype=float32)
# Время эпохи 412 составляет 0.25081682205200195 секунд
# 413/3000: =: tf.Tensor(1.8081198, shape=(), dtype=float32)
# Время эпохи 413 составляет 0.2359936237335205 секунд
# 414/3000: =: tf.Tensor(1.7658099, shape=(), dtype=float32)
# Время эпохи 414 составляет 0.25080156326293945 секунд
# 415/3000: =: tf.Tensor(1.8157141, shape=(), dtype=float32)
# Время эпохи 415 составляет 0.2512674331665039 секунд
# 416/3000: =: tf.Tensor(1.7897232, shape=(), dtype=float32)
# Время эпохи 416 составляет 0.2508268356323242 секунд
# 417/3000: =: tf.Tensor(1.7061994, shape=(), dtype=float32)
# Время эпохи 417 составляет 0.2512814998626709 секунд
# 418/3000: =: tf.Tensor(1.7386767, shape=(), dtype=float32)
# Время эпохи 418 составляет 0.25084352493286133 секунд
# 419/3000: =: tf.Tensor(1.803723, shape=(), dtype=float32)
# Время эпохи 419 составляет 0.2356278896331787 секунд
# 420/3000: =: tf.Tensor(1.797481, shape=(), dtype=float32)
# Время эпохи 420 составляет 0.2664835453033447 секунд
# 421/3000: =: tf.Tensor(1.7954875, shape=(), dtype=float32)
# Время эпохи 421 составляет 0.2663764953613281 секунд
# 422/3000: =: tf.Tensor(1.8240702, shape=(), dtype=float32)
# Время эпохи 422 составляет 0.25089335441589355 секунд
# 423/3000: =: tf.Tensor(1.8535625, shape=(), dtype=float32)
# Время эпохи 423 составляет 0.2512636184692383 секунд
# 424/3000: =: tf.Tensor(1.7742532, shape=(), dtype=float32)
# Время эпохи 424 составляет 0.25080394744873047 секунд
# 425/3000: =: tf.Tensor(1.8219708, shape=(), dtype=float32)
# Время эпохи 425 составляет 0.23561716079711914 секунд
# 426/3000: =: tf.Tensor(1.782114, shape=(), dtype=float32)
# Время эпохи 426 составляет 0.2508199214935303 секунд
# 427/3000: =: tf.Tensor(1.83514, shape=(), dtype=float32)
# Время эпохи 427 составляет 0.251253604888916 секунд
# 428/3000: =: tf.Tensor(1.8118198, shape=(), dtype=float32)
# Время эпохи 428 составляет 0.25084948539733887 секунд
# 429/3000: =: tf.Tensor(1.6849759, shape=(), dtype=float32)
# Время эпохи 429 составляет 0.2507295608520508 секунд
# ...
# 2861/3000: =: tf.Tensor(1.909318, shape=(), dtype=float32)
# Время эпохи 2861 составляет 0.3170647621154785 секунд
# 2862/3000: =: tf.Tensor(1.9658886, shape=(), dtype=float32)
# Время эпохи 2862 составляет 0.3091166019439697 секунд
# 2863/3000: =: tf.Tensor(2.034523, shape=(), dtype=float32)
# Время эпохи 2863 составляет 0.3313632011413574 секунд
# 2864/3000: =: tf.Tensor(1.9593331, shape=(), dtype=float32)
# Время эпохи 2864 составляет 0.304706335067749 секунд
# 2865/3000: =: tf.Tensor(2.03767, shape=(), dtype=float32)
# Время эпохи 2865 составляет 0.32059741020202637 секунд
# 2866/3000: =: tf.Tensor(1.9550664, shape=(), dtype=float32)
# Время эпохи 2866 составляет 0.305889368057251 секунд
# 2867/3000: =: tf.Tensor(1.9842846, shape=(), dtype=float32)
# Время эпохи 2867 составляет 0.31105542182922363 секунд
# 2868/3000: =: tf.Tensor(1.940962, shape=(), dtype=float32)
# Время эпохи 2868 составляет 0.3093409538269043 секунд
# 2869/3000: =: tf.Tensor(1.9365301, shape=(), dtype=float32)
# Время эпохи 2869 составляет 0.30237889289855957 секунд
# 2870/3000: =: tf.Tensor(1.9781615, shape=(), dtype=float32)
# Время эпохи 2870 составляет 0.299405574798584 секунд
# 2871/3000: =: tf.Tensor(1.9893548, shape=(), dtype=float32)
# Время эпохи 2871 составляет 0.2923753261566162 секунд
# 2872/3000: =: tf.Tensor(1.9513386, shape=(), dtype=float32)
# Время эпохи 2872 составляет 0.2934892177581787 секунд
# 2873/3000: =: tf.Tensor(1.9243177, shape=(), dtype=float32)
# Время эпохи 2873 составляет 0.32701873779296875 секунд
# 2874/3000: =: tf.Tensor(1.9723464, shape=(), dtype=float32)
# Время эпохи 2874 составляет 0.438018798828125 секунд
# 2875/3000: =: tf.Tensor(2.008739, shape=(), dtype=float32)
# Время эпохи 2875 составляет 0.31986403465270996 секунд
# 2876/3000: =: tf.Tensor(1.9754814, shape=(), dtype=float32)
# Время эпохи 2876 составляет 0.30814146995544434 секунд
# 2877/3000: =: tf.Tensor(2.058292, shape=(), dtype=float32)
# Время эпохи 2877 составляет 0.296978235244751 секунд
# 2878/3000: =: tf.Tensor(2.1730385, shape=(), dtype=float32)
# Время эпохи 2878 составляет 0.2886850833892822 секунд
# 2879/3000: =: tf.Tensor(2.0466006, shape=(), dtype=float32)
# Время эпохи 2879 составляет 0.2951185703277588 секунд
# 2880/3000: =: tf.Tensor(2.0319638, shape=(), dtype=float32)
# Время эпохи 2880 составляет 0.3000178337097168 секунд
# 2881/3000: =: tf.Tensor(2.0447326, shape=(), dtype=float32)
# Время эпохи 2881 составляет 0.2964777946472168 секунд
# 2882/3000: =: tf.Tensor(2.0042708, shape=(), dtype=float32)
# Время эпохи 2882 составляет 0.29285430908203125 секунд
# 2883/3000: =: tf.Tensor(1.9912815, shape=(), dtype=float32)
# Время эпохи 2883 составляет 0.29610705375671387 секунд
# 2884/3000: =: tf.Tensor(1.9639288, shape=(), dtype=float32)
# Время эпохи 2884 составляет 0.2977440357208252 секунд
# 2885/3000: =: tf.Tensor(1.926281, shape=(), dtype=float32)
# Время эпохи 2885 составляет 0.2921640872955322 секунд
# 2886/3000: =: tf.Tensor(1.9731147, shape=(), dtype=float32)
# Время эпохи 2886 составляет 0.2910318374633789 секунд
# 2887/3000: =: tf.Tensor(1.9850773, shape=(), dtype=float32)
# Время эпохи 2887 составляет 0.2959473133087158 секунд
# 2888/3000: =: tf.Tensor(2.011371, shape=(), dtype=float32)
# Время эпохи 2888 составляет 0.2943150997161865 секунд
# 2889/3000: =: tf.Tensor(1.9824694, shape=(), dtype=float32)
# Время эпохи 2889 составляет 0.29012346267700195 секунд
# 2890/3000: =: tf.Tensor(1.8920205, shape=(), dtype=float32)
# Время эпохи 2890 составляет 0.29665470123291016 секунд
# 2891/3000: =: tf.Tensor(1.9996248, shape=(), dtype=float32)
# Время эпохи 2891 составляет 0.3693397045135498 секунд
# 2892/3000: =: tf.Tensor(1.9516844, shape=(), dtype=float32)
# Время эпохи 2892 составляет 0.292752742767334 секунд
# 2893/3000: =: tf.Tensor(1.9943289, shape=(), dtype=float32)
# Время эпохи 2893 составляет 0.294025182723999 секунд
# 2894/3000: =: tf.Tensor(2.0283768, shape=(), dtype=float32)
# Время эпохи 2894 составляет 0.29762840270996094 секунд
# 2895/3000: =: tf.Tensor(1.9491514, shape=(), dtype=float32)
# Время эпохи 2895 составляет 0.29581332206726074 секунд
# 2896/3000: =: tf.Tensor(2.061868, shape=(), dtype=float32)
# Время эпохи 2896 составляет 0.29633235931396484 секунд
# 2897/3000: =: tf.Tensor(2.0833817, shape=(), dtype=float32)
# Время эпохи 2897 составляет 0.2998542785644531 секунд
# 2898/3000: =: tf.Tensor(2.0380151, shape=(), dtype=float32)
# Время эпохи 2898 составляет 0.2892162799835205 секунд
# 2899/3000: =: tf.Tensor(2.0216167, shape=(), dtype=float32)
# Время эпохи 2899 составляет 0.28804922103881836 секунд
# 2900/3000: =: tf.Tensor(2.0179532, shape=(), dtype=float32)
# Время эпохи 2900 составляет 0.3002479076385498 секунд
# 2901/3000: =: tf.Tensor(1.8421752, shape=(), dtype=float32)
# Время эпохи 2901 составляет 0.30028343200683594 секунд
# 2902/3000: =: tf.Tensor(1.9795625, shape=(), dtype=float32)
# Время эпохи 2902 составляет 0.29999637603759766 секунд
# 2903/3000: =: tf.Tensor(1.9606506, shape=(), dtype=float32)
# Время эпохи 2903 составляет 0.311539888381958 секунд
# 2904/3000: =: tf.Tensor(1.976408, shape=(), dtype=float32)
# Время эпохи 2904 составляет 0.29578566551208496 секунд
# 2905/3000: =: tf.Tensor(2.0664132, shape=(), dtype=float32)
# Время эпохи 2905 составляет 0.41415977478027344 секунд
# 2906/3000: =: tf.Tensor(1.9600878, shape=(), dtype=float32)
# Время эпохи 2906 составляет 0.345172643661499 секунд
# 2907/3000: =: tf.Tensor(1.9698114, shape=(), dtype=float32)
# Время эпохи 2907 составляет 0.30774974822998047 секунд
# 2908/3000: =: tf.Tensor(2.0370102, shape=(), dtype=float32)
# Время эпохи 2908 составляет 0.3162221908569336 секунд
# 2909/3000: =: tf.Tensor(1.9721867, shape=(), dtype=float32)
# Время эпохи 2909 составляет 0.3016090393066406 секунд
# 2910/3000: =: tf.Tensor(1.9250387, shape=(), dtype=float32)
# Время эпохи 2910 составляет 0.28933000564575195 секунд
# 2911/3000: =: tf.Tensor(1.9966252, shape=(), dtype=float32)
# Время эпохи 2911 составляет 0.29097533226013184 секунд
# 2912/3000: =: tf.Tensor(2.1185725, shape=(), dtype=float32)
# Время эпохи 2912 составляет 0.38643646240234375 секунд
# 2913/3000: =: tf.Tensor(2.0028207, shape=(), dtype=float32)
# Время эпохи 2913 составляет 0.3315572738647461 секунд
# 2914/3000: =: tf.Tensor(2.0824714, shape=(), dtype=float32)
# Время эпохи 2914 составляет 0.30570149421691895 секунд
# 2915/3000: =: tf.Tensor(1.9943367, shape=(), dtype=float32)
# Время эпохи 2915 составляет 0.30987024307250977 секунд
# 2916/3000: =: tf.Tensor(1.9415305, shape=(), dtype=float32)
# Время эпохи 2916 составляет 0.29706811904907227 секунд
# 2917/3000: =: tf.Tensor(2.012192, shape=(), dtype=float32)
# Время эпохи 2917 составляет 0.286376953125 секунд
# 2918/3000: =: tf.Tensor(2.037922, shape=(), dtype=float32)
# Время эпохи 2918 составляет 0.33406496047973633 секунд
# 2919/3000: =: tf.Tensor(1.9685608, shape=(), dtype=float32)
# Время эпохи 2919 составляет 0.29156017303466797 секунд
# 2920/3000: =: tf.Tensor(2.0725935, shape=(), dtype=float32)
# Время эпохи 2920 составляет 0.3083689212799072 секунд
# 2921/3000: =: tf.Tensor(2.0178654, shape=(), dtype=float32)
# Время эпохи 2921 составляет 0.30440378189086914 секунд
# 2922/3000: =: tf.Tensor(2.022419, shape=(), dtype=float32)
# Время эпохи 2922 составляет 0.30177783966064453 секунд
# 2923/3000: =: tf.Tensor(1.9845276, shape=(), dtype=float32)
# Время эпохи 2923 составляет 0.3069283962249756 секунд
# 2924/3000: =: tf.Tensor(1.8992289, shape=(), dtype=float32)
# Время эпохи 2924 составляет 0.31957483291625977 секунд
# 2925/3000: =: tf.Tensor(1.9566584, shape=(), dtype=float32)
# Время эпохи 2925 составляет 0.32659411430358887 секунд
# 2926/3000: =: tf.Tensor(2.0251534, shape=(), dtype=float32)
# Время эпохи 2926 составляет 0.3565530776977539 секунд
# 2927/3000: =: tf.Tensor(1.9669062, shape=(), dtype=float32)
# Время эпохи 2927 составляет 0.31092190742492676 секунд
# 2928/3000: =: tf.Tensor(2.009791, shape=(), dtype=float32)
# Время эпохи 2928 составляет 0.2910158634185791 секунд
# 2929/3000: =: tf.Tensor(1.9982843, shape=(), dtype=float32)
# Время эпохи 2929 составляет 0.30498313903808594 секунд
# 2930/3000: =: tf.Tensor(1.9723834, shape=(), dtype=float32)
# Время эпохи 2930 составляет 0.32633137702941895 секунд
# 2931/3000: =: tf.Tensor(1.9847354, shape=(), dtype=float32)
# Время эпохи 2931 составляет 0.318800687789917 секунд
# 2932/3000: =: tf.Tensor(1.8955075, shape=(), dtype=float32)
# Время эпохи 2932 составляет 0.424558162689209 секунд
# 2933/3000: =: tf.Tensor(1.9541391, shape=(), dtype=float32)
# Время эпохи 2933 составляет 0.33257412910461426 секунд
# 2934/3000: =: tf.Tensor(2.0226147, shape=(), dtype=float32)
# Время эпохи 2934 составляет 0.30416059494018555 секунд
# 2935/3000: =: tf.Tensor(1.990887, shape=(), dtype=float32)
# Время эпохи 2935 составляет 0.2890756130218506 секунд
# 2936/3000: =: tf.Tensor(2.0239015, shape=(), dtype=float32)
# Время эпохи 2936 составляет 0.28664541244506836 секунд
# 2937/3000: =: tf.Tensor(2.0658214, shape=(), dtype=float32)
# Время эпохи 2937 составляет 0.2952110767364502 секунд
# 2938/3000: =: tf.Tensor(2.0543704, shape=(), dtype=float32)
# Время эпохи 2938 составляет 0.291776180267334 секунд
# 2939/3000: =: tf.Tensor(2.057591, shape=(), dtype=float32)
# Время эпохи 2939 составляет 0.2887578010559082 секунд
# 2940/3000: =: tf.Tensor(2.0107787, shape=(), dtype=float32)
# Время эпохи 2940 составляет 0.3010115623474121 секунд
# 2941/3000: =: tf.Tensor(2.0515482, shape=(), dtype=float32)
# Время эпохи 2941 составляет 0.29283738136291504 секунд
# 2942/3000: =: tf.Tensor(1.9089698, shape=(), dtype=float32)
# Время эпохи 2942 составляет 0.3006136417388916 секунд
# 2943/3000: =: tf.Tensor(1.8861034, shape=(), dtype=float32)
# Время эпохи 2943 составляет 0.2939622402191162 секунд
# 2944/3000: =: tf.Tensor(2.0445695, shape=(), dtype=float32)
# Время эпохи 2944 составляет 0.29387688636779785 секунд
# 2945/3000: =: tf.Tensor(2.0371165, shape=(), dtype=float32)
# Время эпохи 2945 составляет 0.29299044609069824 секунд
# 2946/3000: =: tf.Tensor(1.9885447, shape=(), dtype=float32)
# Время эпохи 2946 составляет 0.29790353775024414 секунд
# 2947/3000: =: tf.Tensor(1.9480618, shape=(), dtype=float32)
# Время эпохи 2947 составляет 0.292133092880249 секунд
# 2948/3000: =: tf.Tensor(1.9853469, shape=(), dtype=float32)
# Время эпохи 2948 составляет 0.29207944869995117 секунд
# 2949/3000: =: tf.Tensor(1.9462773, shape=(), dtype=float32)
# Время эпохи 2949 составляет 0.2985708713531494 секунд
# 2950/3000: =: tf.Tensor(2.1170547, shape=(), dtype=float32)
# Время эпохи 2950 составляет 0.4823110103607178 секунд
# 2951/3000: =: tf.Tensor(1.9936264, shape=(), dtype=float32)
# Время эпохи 2951 составляет 0.2928192615509033 секунд
# 2952/3000: =: tf.Tensor(1.901743, shape=(), dtype=float32)
# Время эпохи 2952 составляет 0.29043006896972656 секунд
# 2953/3000: =: tf.Tensor(2.0229213, shape=(), dtype=float32)
# Время эпохи 2953 составляет 0.28703737258911133 секунд
# 2954/3000: =: tf.Tensor(2.0135891, shape=(), dtype=float32)
# Время эпохи 2954 составляет 0.2906646728515625 секунд
# 2955/3000: =: tf.Tensor(2.0418375, shape=(), dtype=float32)
# Время эпохи 2955 составляет 0.28672289848327637 секунд
# 2956/3000: =: tf.Tensor(1.9782873, shape=(), dtype=float32)
# Время эпохи 2956 составляет 0.28870677947998047 секунд
# 2957/3000: =: tf.Tensor(2.006253, shape=(), dtype=float32)
# Время эпохи 2957 составляет 0.2945866584777832 секунд
# 2958/3000: =: tf.Tensor(1.9505075, shape=(), dtype=float32)
# Время эпохи 2958 составляет 0.29279184341430664 секунд
# 2959/3000: =: tf.Tensor(1.971134, shape=(), dtype=float32)
# Время эпохи 2959 составляет 0.2984347343444824 секунд
# 2960/3000: =: tf.Tensor(2.0933783, shape=(), dtype=float32)
# Время эпохи 2960 составляет 0.2885475158691406 секунд
# 2961/3000: =: tf.Tensor(1.896651, shape=(), dtype=float32)
# Время эпохи 2961 составляет 0.2950127124786377 секунд
# 2962/3000: =: tf.Tensor(2.044328, shape=(), dtype=float32)
# Время эпохи 2962 составляет 0.3107917308807373 секунд
# 2963/3000: =: tf.Tensor(1.9967774, shape=(), dtype=float32)
# Время эпохи 2963 составляет 0.3296182155609131 секунд
# 2964/3000: =: tf.Tensor(1.9869093, shape=(), dtype=float32)
# Время эпохи 2964 составляет 0.30173826217651367 секунд
# 2965/3000: =: tf.Tensor(1.8831176, shape=(), dtype=float32)
# Время эпохи 2965 составляет 0.29300832748413086 секунд
# 2966/3000: =: tf.Tensor(1.99257, shape=(), dtype=float32)
# Время эпохи 2966 составляет 0.3000977039337158 секунд
# 2967/3000: =: tf.Tensor(2.0369117, shape=(), dtype=float32)
# Время эпохи 2967 составляет 0.3390345573425293 секунд
# 2968/3000: =: tf.Tensor(2.0302114, shape=(), dtype=float32)
# Время эпохи 2968 составляет 0.42805004119873047 секунд
# 2969/3000: =: tf.Tensor(1.9884616, shape=(), dtype=float32)
# Время эпохи 2969 составляет 0.29543018341064453 секунд
# 2970/3000: =: tf.Tensor(2.102997, shape=(), dtype=float32)
# Время эпохи 2970 составляет 0.2886958122253418 секунд
# 2971/3000: =: tf.Tensor(2.0131526, shape=(), dtype=float32)
# Время эпохи 2971 составляет 0.29148030281066895 секунд
# 2972/3000: =: tf.Tensor(2.0030198, shape=(), dtype=float32)
# Время эпохи 2972 составляет 0.288485050201416 секунд
# 2973/3000: =: tf.Tensor(1.8753903, shape=(), dtype=float32)
# Время эпохи 2973 составляет 0.37209439277648926 секунд
# 2974/3000: =: tf.Tensor(2.132954, shape=(), dtype=float32)
# Время эпохи 2974 составляет 0.32416367530822754 секунд
# 2975/3000: =: tf.Tensor(1.9825135, shape=(), dtype=float32)
# Время эпохи 2975 составляет 0.31210994720458984 секунд
# 2976/3000: =: tf.Tensor(1.9903761, shape=(), dtype=float32)
# Время эпохи 2976 составляет 0.3016624450683594 секунд
# 2977/3000: =: tf.Tensor(1.9773443, shape=(), dtype=float32)
# Время эпохи 2977 составляет 0.30062365531921387 секунд
# 2978/3000: =: tf.Tensor(1.981867, shape=(), dtype=float32)
# Время эпохи 2978 составляет 0.29788804054260254 секунд
# 2979/3000: =: tf.Tensor(2.018606, shape=(), dtype=float32)
# Время эпохи 2979 составляет 0.28900957107543945 секунд
# 2980/3000: =: tf.Tensor(1.9832513, shape=(), dtype=float32)
# Время эпохи 2980 составляет 0.29402685165405273 секунд
# 2981/3000: =: tf.Tensor(1.99642, shape=(), dtype=float32)
# Время эпохи 2981 составляет 0.29181337356567383 секунд
# 2982/3000: =: tf.Tensor(1.9924221, shape=(), dtype=float32)
# Время эпохи 2982 составляет 0.29189348220825195 секунд
# 2983/3000: =: tf.Tensor(2.0146446, shape=(), dtype=float32)
# Время эпохи 2983 составляет 0.29998183250427246 секунд
# 2984/3000: =: tf.Tensor(1.9613104, shape=(), dtype=float32)
# Время эпохи 2984 составляет 0.2843441963195801 секунд
# 2985/3000: =: tf.Tensor(1.9115149, shape=(), dtype=float32)
# Время эпохи 2985 составляет 0.34851551055908203 секунд
# 2986/3000: =: tf.Tensor(1.994696, shape=(), dtype=float32)
# Время эпохи 2986 составляет 0.304762601852417 секунд
# 2987/3000: =: tf.Tensor(1.9953634, shape=(), dtype=float32)
# Время эпохи 2987 составляет 0.2876589298248291 секунд
# 2988/3000: =: tf.Tensor(2.0764453, shape=(), dtype=float32)
# Время эпохи 2988 составляет 0.30080413818359375 секунд
# 2989/3000: =: tf.Tensor(2.0689757, shape=(), dtype=float32)
# Время эпохи 2989 составляет 0.2906811237335205 секунд
# 2990/3000: =: tf.Tensor(1.9488, shape=(), dtype=float32)
# Время эпохи 2990 составляет 0.29196691513061523 секунд
# 2991/3000: =: tf.Tensor(1.9751562, shape=(), dtype=float32)
# Время эпохи 2991 составляет 0.28969883918762207 секунд
# 2992/3000: =: tf.Tensor(2.0074737, shape=(), dtype=float32)
# Время эпохи 2992 составляет 0.28824734687805176 секунд
# 2993/3000: =: tf.Tensor(2.001679, shape=(), dtype=float32)
# Время эпохи 2993 составляет 0.28556370735168457 секунд
# 2994/3000: =: tf.Tensor(1.9965256, shape=(), dtype=float32)
# Время эпохи 2994 составляет 0.29408907890319824 секунд
# 2995/3000: =: tf.Tensor(1.95129, shape=(), dtype=float32)
# Время эпохи 2995 составляет 0.2838735580444336 секунд
# 2996/3000: =: tf.Tensor(1.9831079, shape=(), dtype=float32)
# Время эпохи 2996 составляет 0.29076647758483887 секунд
# 2997/3000: =: tf.Tensor(2.0026143, shape=(), dtype=float32)
# Время эпохи 2997 составляет 0.29181766510009766 секунд
# 2998/3000: =: tf.Tensor(1.9966094, shape=(), dtype=float32)
# Время эпохи 2998 составляет 0.31519341468811035 секунд
# 2999/3000: =: tf.Tensor(2.0771966, shape=(), dtype=float32)
# Время эпохи 2999 составляет 0.29004979133605957 секунд
# 3000/3000: =: tf.Tensor(2.0382237, shape=(), dtype=float32)
# Время эпохи 3000 составляет 0.2932100296020508 секунд

# %%
noise = tf.random.normal([BATCH_SIZE, hidden_dim])
generated_images = generator(noise)
plt.imshow(generated_images[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(5, 5))
num = 1
for i in range(25):
    noise = tf.random.normal([BATCH_SIZE, hidden_dim])
    ax = plt.subplot(total, total, num)
    num += 1
    img = generator(noise)
    plt.imshow(img[0])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
generator.save('20x20_strawberry_gen_7000.keras')

# %%
discriminator.save('20x20_strawberry_disc_7000.keras')
